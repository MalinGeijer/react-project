# %%
#%pip install tensorflow
from tensorflow import keras
from keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the MNIST dataset to memory
# x_train = training images
# y_train = training labels, i.e., the correct answers number 0-9
# x_test = test images
# y_test = test labels, i.e., the correct answers number 0-9
# Split the data into a training set and a test set.
# The test set is used to evaluate the model after training. New images that the model has never seen before. Preventing overfitting. No guessing.

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# Print the shape of the training and test datasets (to understand their structure)
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)

# %%
# Utför en enkel exploratory data analysis (EDA) – t.ex. med hjälp av matplotlib
# eller seaborn.
plt.figure(figsize=(6, 6))

for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(x_train[i], cmap="gray")
    plt.title(f"Label: {y_train[i]}")
    plt.axis("off")

plt.show()

# %%
x_train.min(), x_train.max(), x_train.mean()

# %%
counts = np.bincount(y_train)
counts
plt.bar(range(10), counts)
plt.xlabel("Siffra")
plt.ylabel("Antal")
plt.title("Fördelning av siffror i träningsdatan")
plt.show()
